# %%
import requests
import json
from dotenv import load_dotenv
import os


load_dotenv()

def fetch_line_reports():
    # URL API
    url = 'https://api.navitia.io/v1/coverage/fr-idf/line_reports'

    # clé api from env
    api_key = os.getenv('token_navitia')
    headers = {
        'Authorization': api_key
    }
    
    # requete
    response = requests.get(url, headers=headers)

  
    if response.status_code == 200:
       
        data = response.json()
        # ecriture requete positif en hson
        with open('line_reports.json', 'w') as json_file:
            json.dump(data, json_file, indent=4)
        print("Data written to line_reports.json")
    else:
        
        print('Failed to retrieve data: ', response.status_code)

# Appel func
fetch_traffic_reports()
# Out:
# Data written to line_reports.json

# %%
import pandas as pd
from datetime import datetime

with open('line_reports.json') as f:
    data = json.load(f)

disruptions_data = []

for disruption in data['disruptions']:
    for impacted_object in disruption['impacted_objects']:
        pt_object = impacted_object['pt_object']
        # Check 'stop_point' key existe 
        
        if 'stop_point' in pt_object:  
            stop_point = pt_object['stop_point']
            location_name = stop_point['name']
            location_label = stop_point['label']
            longitude = stop_point['coord']['lon']
            latitude = stop_point['coord']['lat']
            address_label = stop_point['address']['label']
            fare_zone = stop_point['fare_zone']['name']
            transport_type = pt_object['embedded_type']
        else:
            # none si on trouve pas
            location_name = location_label = longitude = latitude = address_label = fare_zone = transport_type = None
        
        # check pour le mode de transport quand il se trouve dedans
        if 'line' in pt_object and 'physical_modes' in pt_object['line']:
            physical_mode = pt_object['line']['physical_modes'][0]['name']
        else:
            physical_mode = None

        disruption_info = {
            "disruption_id": disruption['id'],
            "status": disruption['status'],
            "cause": disruption['cause'],
            "category": disruption['category'],
            "severity_name": disruption['severity']['name'],
            "severity_effect": disruption['severity']['effect'],
            "severity_color": disruption['severity']['color'],
            "severity_priority": disruption['severity']['priority'],
            "message_text": disruption['messages'][0]['text'],
            "application_period_begin": datetime.strptime(disruption['application_periods'][0]['begin'], '%Y%m%dT%H%M%S'),
            "application_period_end": datetime.strptime(disruption['application_periods'][0]['end'], '%Y%m%dT%H%M%S'),
            "location_name": location_name,
            "location_label": location_label,
            "longitude": longitude,
            "latitude": latitude,
            "address_label": address_label,
            "fare_zone": fare_zone,
            "transport_type": transport_type,
            "physical_mode": physical_mode
        }
        
        disruptions_data.append(disruption_info)

# dataframe gang
df_disruptions = pd.DataFrame(disruptions_data)

df_disruptions
# Out:
#                             disruption_id  status         cause   category  \
# 0    e9cbe72a-04c5-11ef-9db7-0a58a9feac02  active       travaux  Incidents
# 1    e9cbe72a-04c5-11ef-9db7-0a58a9feac02  active       travaux  Incidents
# 2    e9cbe72a-04c5-11ef-9db7-0a58a9feac02  active       travaux  Incidents
# 3    e9cbe72a-04c5-11ef-9db7-0a58a9feac02  active       travaux  Incidents
# 4    e9cbe72a-04c5-11ef-9db7-0a58a9feac02  active       travaux  Incidents
# ..                                    ...     ...           ...        ...
# 99   f7588214-069a-11ef-98d5-0a58a9feac02  active  perturbation  Incidents
# 100  f7588214-069a-11ef-98d5-0a58a9feac02  active  perturbation  Incidents
# 101  f7588214-069a-11ef-98d5-0a58a9feac02  active  perturbation  Incidents
# 102  f7588214-069a-11ef-98d5-0a58a9feac02  active  perturbation  Incidents
# 103  f7588214-069a-11ef-98d5-0a58a9feac02  active  perturbation  Incidents
#
#     severity_name     severity_effect severity_color  severity_priority  \
# 0       bloquante          NO_SERVICE        #FF0000                  0
# 1       bloquante          NO_SERVICE        #FF0000                  0
# 2       bloquante          NO_SERVICE        #FF0000                  0
# 3       bloquante          NO_SERVICE        #FF0000                  0
# 4       bloquante          NO_SERVICE        #FF0000                  0
# ..            ...                 ...            ...                ...
# 99      perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 100     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 101     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 102     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 103     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
#
#                                           message_text  \
# 0    <p>La ligne 272 est déviée : les arrêts situés...
# 1    <p>La ligne 272 est déviée : les arrêts situés...
# 2    <p>La ligne 272 est déviée : les arrêts situés...
# 3    <p>La ligne 272 est déviée : les arrêts situés...
# 4    <p>La ligne 272 est déviée : les arrêts situés...
# ..                                                 ...
# 99   <p><span style="background-color:rgb(255,255,2...
# 100  <p><span style="background-color:rgb(255,255,2...
# 101  <p><span style="background-color:rgb(255,255,2...
# 102  <p><span style="background-color:rgb(255,255,2...
# 103  <p><span style="background-color:rgb(255,255,2...
#
#     application_period_begin application_period_end  \
# 0        2024-04-17 06:00:00    2024-06-01 03:45:00
# 1        2024-04-17 06:00:00    2024-06-01 03:45:00
# 2        2024-04-17 06:00:00    2024-06-01 03:45:00
# 3        2024-04-17 06:00:00    2024-06-01 03:45:00
# 4        2024-04-17 06:00:00    2024-06-01 03:45:00
# ..                       ...                    ...
# 99       2024-04-29 17:15:00    2024-04-30 23:59:00
# 100      2024-04-29 17:15:00    2024-04-30 23:59:00
# 101      2024-04-29 17:15:00    2024-04-30 23:59:00
# 102      2024-04-29 17:15:00    2024-04-30 23:59:00
# 103      2024-04-29 17:15:00    2024-04-30 23:59:00
#
#                           location_name  \
# 0                          Clément Ader
# 1    Charles de Gaulle - Henri Barbusse
# 2                  Place du 11 Novembre
# 3                     Avenue du Château
# 4                                  None
# ..                                  ...
# 99                                 None
# 100                                None
# 101                                None
# 102                                None
# 103                                None
#
#                                       location_label longitude   latitude  \
# 0                          Clément Ader (Argenteuil)   2.24347  48.942583
# 1    Charles de Gaulle - Henri Barbusse (Argenteuil)  2.245179  48.940498
# 2                  Place du 11 Novembre (Argenteuil)  2.239094  48.936521
# 3                     Avenue du Château (Argenteuil)  2.233204  48.933282
# 4                                               None      None       None
# ..                                               ...       ...        ...
# 99                                              None      None       None
# 100                                             None      None       None
# 101                                             None      None       None
# 102                                             None      None       None
# 103                                             None      None       None
#
#                                 address_label fare_zone transport_type  \
# 0           Rue de la Tour Billy (Argenteuil)         4     stop_point
# 1    Avenue du Général de Gaulle (Argenteuil)         4     stop_point
# 2        Nouvelle Impasse Duguay (Argenteuil)         4     stop_point
# 3              Allée Simone Veil (Argenteuil)         4     stop_point
# 4                                        None      None           None
# ..                                        ...       ...            ...
# 99                                       None      None           None
# 100                                      None      None           None
# 101                                      None      None           None
# 102                                      None      None           None
# 103                                      None      None           None
#
#     physical_mode
# 0            None
# 1            None
# 2            None
# 3            None
# 4             Bus
# ..            ...
# 99            Bus
# 100           Bus
# 101           Bus
# 102           Bus
# 103           Bus
#
# [104 rows x 19 columns]

# %%
from meteofrance_api import MeteoFranceClient

# Create a client instance
client = MeteoFranceClient()

# Search for a location
places = client.search_places('Paris')

# Get the forecast for the first result
forecast = client.get_forecast_for_place(places[0])

# Print the forecast data
print(forecast.daily_forecast)
# Out:
# [{'dt': 1714435200, 'T': {'min': 12.6, 'max': 19.1, 'sea': None}, 'humidity': {'min': 65, 'max': 90}, 'precipitation': {'24h': 0.8}, 'uv': 4, 'weather12H': {'icon': 'p3j', 'desc': 'Très nuageux'}, 'sun': {'rise': 1714451455, 'set': 1714503928}}, {'dt': 1714521600, 'T': {'min': 14.1, 'max': 20.2, 'sea': None}, 'humidity': {'min': 65, 'max': 90}, 'precipitation': {'24h': 8.5}, 'uv': 4, 'weather12H': {'icon': 'p13j', 'desc': 'Pluies éparses'}, 'sun': {'rise': 1714537753, 'set': 1714590415}}, {'dt': 1714608000, 'T': {'min': 12.1, 'max': 14.1, 'sea': None}, 'humidity': {'min': 80, 'max': 95}, 'precipitation': {'24h': 5.5}, 'uv': 3, 'weather12H': {'icon': 'p13j', 'desc': 'Pluies éparses'}, 'sun': {'rise': 1714624052, 'set': 1714676902}}, {'dt': 1714694400, 'T': {'min': 10.5, 'max': 16.6, 'sea': None}, 'humidity': {'min': 65, 'max': 95}, 'precipitation': {'24h': 0}, 'uv': 4, 'weather12H': {'icon': 'p2j', 'desc': 'Eclaircies'}, 'sun': {'rise': 1714710353, 'set': 1714763389}}, {'dt': 1714780800, 'T': {'min': 9.5, 'max': 18}, 'humidity': {'min': 65, 'max': 95}, 'precipitation': {'24h': 0.9}, 'uv': None, 'weather12H': {'icon': 'p14bisj', 'desc': 'Averses'}, 'sun': {'rise': 1714796655, 'set': 1714849876}}, {'dt': 1714867200, 'T': {'min': 12.1, 'max': 20.1}, 'humidity': {'min': 65, 'max': 95}, 'precipitation': {'24h': 0.7}, 'uv': None, 'weather12H': {'icon': 'p14bisj', 'desc': 'Averses'}, 'sun': {'rise': 1714882959, 'set': 1714936362}}, {'dt': 1714953600, 'T': {'min': 13.2, 'max': 22.1}, 'humidity': {'min': 65, 'max': 95}, 'precipitation': {'24h': 0}, 'uv': None, 'weather12H': {'icon': 'p3j', 'desc': 'Très nuageux'}, 'sun': {'rise': 1714969264, 'set': 1715022847}}, {'dt': 1715040000, 'T': {'min': 14, 'max': 22.1}, 'humidity': {'min': 65, 'max': 95}, 'precipitation': {'24h': 3.8}, 'uv': None, 'weather12H': {'icon': 'p26j', 'desc': "Risque d'orages"}, 'sun': {'rise': 1715055570, 'set': 1715109333}}, {'dt': 1715126400, 'T': {'min': 13.1, 'max': 21.1}, 'humidity': {'min': 60, 'max': 95}, 'precipitation': {'24h': 0}, 'uv': None, 'weather12H': {'icon': 'p2j', 'desc': 'Eclaircies'}, 'sun': {'rise': 1715141879, 'set': 1715195817}}, {'dt': 1715212800, 'T': {'min': 12.4, 'max': 21.9}, 'humidity': {'min': 60, 'max': 90}, 'precipitation': {'24h': 0}, 'uv': None, 'weather12H': {'icon': 'p2j', 'desc': 'Eclaircies'}, 'sun': {'rise': 1715228189, 'set': 1715282302}}, {'dt': 1715299200, 'T': {'min': 12, 'max': 22.1}, 'humidity': {'min': 60, 'max': 90}, 'precipitation': {'24h': 0}, 'uv': None, 'weather12H': {'icon': 'p2j', 'desc': 'Eclaircies'}, 'sun': {'rise': 1715314501, 'set': 1715368785}}, {'dt': 1715385600, 'T': {'min': 11.7, 'max': 22.5}, 'humidity': {'min': 60, 'max': 90}, 'precipitation': {'24h': 0}, 'uv': None, 'weather12H': {'icon': 'p1j', 'desc': 'Ensoleillé'}, 'sun': {'rise': 1715400814, 'set': 1715455268}}, {'dt': 1715472000, 'T': {'min': 11.6, 'max': 22.2}, 'humidity': {'min': 60, 'max': 90}, 'precipitation': {'24h': 0}, 'uv': None, 'weather12H': {'icon': 'p1j', 'desc': 'Ensoleillé'}, 'sun': {'rise': 1715487129, 'set': 1715541750}}, {'dt': 1715558400, 'T': {'min': 11.6, 'max': 21.1}, 'humidity': {'min': 60, 'max': 90}, 'precipitation': {'24h': 0}, 'uv': None, 'weather12H': {'icon': 'p1j', 'desc': 'Ensoleillé'}, 'sun': {'rise': 1715573446, 'set': 1715628232}}, {'dt': 1715644800, 'T': {'min': 11.6, 'max': 21.7}, 'humidity': {'min': 55, 'max': 90}, 'precipitation': {'24h': 0}, 'uv': None, 'weather12H': {'icon': 'p1j', 'desc': 'Ensoleillé'}, 'sun': {'rise': 1715659765, 'set': 1715714713}}]

# %%
rain_data = client.get_rain()
print(rain_data.forecast)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 rain_data = client.get_rain()
#       2 print(rain_data.forecast)
#
# TypeError: MeteoFranceClient.get_rain() missing 2 required positional arguments: 'latitude' and 'longitude'

# %%
from meteofrance_api import MeteoFranceClient
from datetime import datetime, timedelta

client = MeteoFranceClient()

# Supposons que cette fonction puisse récupérer des données historiques
def fetch_weather_data(place, start_date, end_date):
    current_date = start_date
    weather_data = []
    while current_date <= end_date:
        forecast = client.get_historical_data(place, current_date)
        weather_data.append(forecast)
        current_date += timedelta(days=1)  # Incrément journalier
    return weather_data

# Recherche du lieu
places = client.search_places('Paris')

# Définir les dates de début et de fin pour l'année 2023
start_date = datetime(2023, 1, 1)
end_date = datetime(2023, 12, 31)

# Récupérer les données météo
weather_data = fetch_weather_data(places[0], start_date, end_date)
print(weather_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 24
#      21 end_date = datetime(2023, 12, 31)
#      23 # Récupérer les données météo
# ---> 24 weather_data = fetch_weather_data(places[0], start_date, end_date)
#      25 print(weather_data)
#
# Cell In[6], line 11, in fetch_weather_data(place, start_date, end_date)
#       9 weather_data = []
#      10 while current_date <= end_date:
# ---> 11     forecast = client.get_historical_data(place, current_date)
#      12     weather_data.append(forecast)
#      13     current_date += timedelta(days=1)  # Incrément journalier
#
# AttributeError: 'MeteoFranceClient' object has no attribute 'get_historical_data'

# %%
import pandas as pd

df = pd.read_csv('Q_01_previous-1950-2022_RR-T-Vent.csv', delimiter=';')
df
# Out:
#         NUM_POSTE  NOM_USUEL        LAT       LON  ALTI  AAAAMMJJ    RR  QRR  \
# 0         1010001  ANGLEFORT  45.900000  5.766667   280  19500101   0.0  1.0
# 1         1010001  ANGLEFORT  45.900000  5.766667   280  19500102   0.0  1.0
# 2         1010001  ANGLEFORT  45.900000  5.766667   280  19500103  13.8  1.0
# 3         1010001  ANGLEFORT  45.900000  5.766667   280  19500104   5.4  1.0
# 4         1010001  ANGLEFORT  45.900000  5.766667   280  19500105   0.0  1.0
# ...           ...        ...        ...       ...   ...       ...   ...  ...
# 955878    1457001     VONNAS  46.218333  4.990000   190  19920327   0.9  1.0
# 955879    1457001     VONNAS  46.218333  4.990000   190  19920328   0.7  1.0
# 955880    1457001     VONNAS  46.218333  4.990000   190  19920329   0.0  1.0
# 955881    1457001     VONNAS  46.218333  4.990000   190  19920330  18.6  1.0
# 955882    1457001     VONNAS  46.218333  4.990000   190  19920331   5.0  1.0
#
#         TN  QTN  ...  DXI2  QDXI2  HXI2  QHXI2  FXI3S  QFXI3S  DXI3S  QDXI3S  \
# 0      NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN    NaN     NaN
# 1      NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN    NaN     NaN
# 2      NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN    NaN     NaN
# 3      NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN    NaN     NaN
# 4      NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN    NaN     NaN
# ...     ..  ...  ...   ...    ...   ...    ...    ...     ...    ...     ...
# 955878 NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN    NaN     NaN
# 955879 NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN    NaN     NaN
# 955880 NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN    NaN     NaN
# 955881 NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN    NaN     NaN
# 955882 NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN    NaN     NaN
#
#         HXI3S  QHXI3S
# 0         NaN     NaN
# 1         NaN     NaN
# 2         NaN     NaN
# 3         NaN     NaN
# 4         NaN     NaN
# ...       ...     ...
# 955878    NaN     NaN
# 955879    NaN     NaN
# 955880    NaN     NaN
# 955881    NaN     NaN
# 955882    NaN     NaN
#
# [955883 rows x 56 columns]

# %%
import pandas as pd
import os
from collections import defaultdict

# Function to parse descriptive files
def parse_descriptive_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    field_names = {}
    for line in lines:
        parts = line.strip().split(":")
        if len(parts) == 2:
            field, description = parts
            field_names[field.strip()] = description.strip()
    return field_names

# Base directory for files (update with the correct path to your CSVs)
base_dir = './'

# Descriptive field mappings
desc_fields = {
    'autres-parametres': parse_descriptive_file(os.path.join(base_dir, 'Q_descriptif_champs_autres-parametres.csv')),
    'RR-T-Vent': parse_descriptive_file(os.path.join(base_dir, 'Q_descriptif_champs_RR-T-Vent.csv'))
}

# Function to process and concatenate datasets
def process_and_concatenate_datasets():
    # Dictionaries to store dataframes grouped by year
    dataframes = {
        'autres-parametres': defaultdict(list),
        'RR-T-Vent': defaultdict(list)
    }
    
    # Read and group datasets by year
    for filename in os.listdir(base_dir):
        if filename.endswith('.csv') and 'descriptif' not in filename:
            print(f"Reading {filename}...")
            year_group = filename.split('_')[1]  # Assumes the year is the second element in the filename
            file_type = 'autres-parametres' if 'autres-parametres' in filename else 'RR-T-Vent'
            dataset = pd.read_csv(os.path.join(base_dir, filename), sep=';')
            dataframes[file_type][year_group].append(dataset)
    
    # Concatenate dataframes within the same year and apply descriptive fields
    concatenated_datasets = {}
    for file_type, year_groups in dataframes.items():
        for year, dfs in year_groups.items():
            concatenated_df = pd.concat(dfs, ignore_index=True)
            concatenated_df.rename(columns=desc_fields[file_type], inplace=True)
            concatenated_datasets[f"{file_type}_{year}"] = concatenated_df
            print(f"Processed and concatenated {file_type} for {year}")
    
    return concatenated_datasets

# Execute the function and get the processed datasets
concatenated_datasets = process_and_concatenate_datasets()
# Out:
# Reading Q_75_1816-1949_autres-parametres.csv...
# Reading Q_75_1816-1949_RR-T-Vent.csv...
# Reading Q_75_latest-2023-2024_autres-parametres.csv...
# Reading Q_75_latest-2023-2024_RR-T-Vent.csv...
# Reading Q_75_previous-1950-2022_autres-parametres.csv...
# Reading Q_75_previous-1950-2022_RR-T-Vent.csv...
# Processed and concatenated autres-parametres for 75
# Processed and concatenated RR-T-Vent for 75
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 58
#      55 concatenated_datasets = process_and_concatenate_datasets()
#      57 # Example to access a specific dataset
# ---> 58 concatenated_datasets['Q_75'].head()
#
# KeyError: 'Q_75'

# %%
import pandas as pd
import numpy as np

# List of strings that are recognized as NaN values
na = ['NaN', 'nan', 'NAN', ' NaN', 'NAN ']

# Load the datasets, converting "NaN" strings to actual NaN values
df1 = pd.read_csv('Q_75_previous-1950-2022_autres-parametres.csv', sep=';', na_values=na)
df2 = pd.read_csv('Q_75_previous-1950-2022_RR-T-Vent.csv', sep=';', na_values=na)

# Merge the datasets on the 'AAAAMMJJ' column using an outer join
merged_df = pd.merge(df1, df2, on='AAAAMMJJ', how='outer')

# Drop columns where all elements are NaN post-merge
merged_df.dropna(axis=1, how='all', inplace=True)

# After merging and dropping fully empty columns, recheck and drop any columns that might have become completely NaN
merged_df.dropna(axis=1, how='all', inplace=True)

# Display the first few rows of the merged DataFrame to verify the results
print(merged_df.head())
# Out:
#    NUM_POSTE_x       NOM_USUEL_x      LAT_x     LON_x  ALTI_x  AAAAMMJJ  \
# 0     75114001  PARIS-MONTSOURIS  48.821667  2.337833      75  19500101
# 1     75114001  PARIS-MONTSOURIS  48.821667  2.337833      75  19500101
# 2     75114001  PARIS-MONTSOURIS  48.821667  2.337833      75  19500101
# 3     75114001  PARIS-MONTSOURIS  48.821667  2.337833      75  19500101
# 4     75114001  PARIS-MONTSOURIS  48.821667  2.337833      75  19500101
#
#    PMERM  QPMERM  PMERMIN  QPMERMIN  ...  QFXI  DXI  QDXI  HXI  QHXI  FXI3S  \
# 0    NaN     NaN      NaN       NaN  ...   NaN  NaN   NaN  NaN   NaN    NaN
# 1    NaN     NaN      NaN       NaN  ...   NaN  NaN   NaN  NaN   NaN    NaN
# 2    NaN     NaN      NaN       NaN  ...   NaN  NaN   NaN  NaN   NaN    NaN
# 3    NaN     NaN      NaN       NaN  ...   NaN  NaN   NaN  NaN   NaN    NaN
# 4    NaN     NaN      NaN       NaN  ...   NaN  NaN   NaN  NaN   NaN    NaN
#
#    QFXI3S  QDXI3S  HXI3S  QHXI3S
# 0     NaN     NaN    NaN     NaN
# 1     NaN     NaN    NaN     NaN
# 2     NaN     NaN    NaN     NaN
# 3     NaN     NaN    NaN     NaN
# 4     NaN     NaN    NaN     NaN
#
# [5 rows x 117 columns]

# %%
for column in merged_df.columns:
    # Get unique values in each column
    unique_values = merged_df[column].unique()
    # Print the column name and its unique values
    print(f"Unique values in '{column}': {unique_values}\n")
# Out:
# Unique values in 'NUM_POSTE_x': [75114001 75112001 75116003 75104001 75110002 75119002 75116002 75112004
#  75113001 75107001 75118001 75120002 75110001 75119004 75105001 75108001
#  75114003 75112002 75116001 75101001 75114002 75120001 75106001 75119001
#  75115001 75107004 75112003 75120004 75116005 75117001 75113002 75120005
#  75120006 75107005 75115003 75116008 75114007]
#
# Unique values in 'NOM_USUEL_x': ['PARIS-MONTSOURIS' 'ILE DE BERCY' 'PASSY' 'TOUR ST-JACQUES' 'ST-LOUIS'
#  'VILLETTE' 'BAGATELLE' 'ST-ANTOINE' "PORTE D'IVRY" 'LAENNEC' 'MONTMARTRE'
#  'MENIL.RESERVOIR' 'LARIBOISIERE' 'BUTTES RESERV.' 'PLANTES' 'LOUIS XVI'
#  0.  5.4 5.8 6.  7.3 7.1 6.3 6.6 5.6 6.1 7.  6.8 7.9 6.7 7.6 8.8 7.5 5.9
#  6.2 8.1 8.2 6.4 6.9 4.4 5.3 6.5 7.2 7.4 7.8 8.4 8.9 8.6 9.  8.  7.7 8.3
#  8.5 8.7]
#
# Unique values in 'QETPMON': [nan  1.  9.  2.]
#
# Unique values in 'ETPGRILLE': [nan 0.5 0.6 0.7 0.9 0.2 0.4 0.3 0.8 1.3 1.7 1.  1.6 3.1 2.1 2.5 1.5 1.1
#  1.8 1.4 0.1 1.2 2.3 2.7 3.3 2.9 2.6 2.  1.9 2.2 3.4 3.6 3.9 2.4 4.4 4.6
#  4.3 2.8 4.7 3.  3.8 4.1 4.5 4.8 5.2 5.1 5.7 3.2 3.5 4.  5.  5.6 6.  6.3
#  6.5 5.4 4.2 5.5 6.1 5.3 5.9 6.2 6.8 5.8 7.6 7.9 6.6 6.7 6.4 7.5 7.4 7.1
#  6.9 8.2 8.  3.7 4.9 7.3 7.2 7.  0.  8.5 8.3 7.7 8.1 7.8 8.6 8.9 9.  8.4
#  8.7 8.8]
#
# Unique values in 'QETPGRILLE': [nan  9.]
#
# Unique values in 'HNEIGEF': [nan  0.  1.  3.  5.  2.  4.  7. 13. 10. 11.  8.  6. 12.  9.]
#
# Unique values in 'QHNEIGEF': [nan  9.  1.]
#
# Unique values in 'NEIGETOTX': [nan  7.  3.  1.  4.  9. 11.  8. 10.  5.  0.  2. 12. 14.  6. 20. 17. 13.
#  15. 18. 22.]
#
# Unique values in 'QNEIGETOTX': [ 1. nan  9.]
#
# Unique values in 'NEIGETOT06': [nan  9. 12. 14. 10.  8.  5.  2.  1.  0.  3.  4.  6.  7. 13. 11. 20. 15.
#  18. 22.]
#
# Unique values in 'QNEIGETOT06': [nan  1.  9.]
#
# Unique values in 'NEIG': [ 0.  1. nan]
#
# Unique values in 'QNEIG': [ 9.  1. nan  2.]
#
# Unique values in 'BROU': [nan  0.  1.]
#
# Unique values in 'QBROU': [nan  1.  9.]
#
# Unique values in 'ORAG': [ 0. nan  1.]
#
# Unique values in 'QORAG': [ 9. nan  1.]
#
# Unique values in 'GRESIL': [ 0. nan  1.]
#
# Unique values in 'QGRESIL': [ 9. nan  1.]
#
# Unique values in 'GRELE': [ 0. nan  1.]
#
# Unique values in 'QGRELE': [ 9. nan  1.]
#
# Unique values in 'ROSEE': [nan  0.  1.]
#
# Unique values in 'QROSEE': [nan  1.  9.]
#
# Unique values in ' VERGLAS': [nan  0.  1.]
#
# Unique values in 'QVERGLAS': [nan  9.  1.]
#
# Unique values in 'SOLNEIGE': [nan  0.  1.]
#
# Unique values in 'QSOLNEIGE': [nan  9.  1.]
#
# Unique values in 'GELEE': [nan  0.  1.]
#
# Unique values in 'QGELEE': [nan  1.  9.  2.]
#
# Unique values in 'FUMEE': [nan  0.  1.]
#
# Unique values in 'QFUMEE': [nan  9.  1.]
#
# Unique values in 'BRUME': [nan  1.  0.]
#
# Unique values in 'QBRUME': [nan  9.  1.]
#
# Unique values in 'ECLAIR': [nan  0.  1.]
#
# Unique values in 'QECLAIR': [nan  9.  1.]
#
# Unique values in 'NB300': [nan  8.  7.  5.  6.]
#
# Unique values in 'QNB300': [nan  1.  9.]
#
# Unique values in 'BA300': [ nan 160. 150. 200. 180. 100. 250. 240. 270. 280.   0. 120. 290.  25.
#   40. 210.  50. 220. 260.  80.  60.  70.   8. 230. 170.  90.  20.]
#
# Unique values in 'QBA300': [nan  1.  9.]
#
# Unique values in 'NUM_POSTE_y': [75101001 75104001 75105001 75107001 75108001 75110001 75110002 75112001
#  75112002 75112004 75113001 75114001 75114002 75114003 75116001 75116002
#  75116003 75118001 75119002 75119003 75119004 75120001 75120002 75106001
#  75119001 75115001 75112003 75107004 75120004 75116005 75117001 75113002
#  75120005 75120006 75107005 75115003 75116008 75114007]
#
# Unique values in 'NOM_USUEL_y': ['INNOCENTS' 'TOUR ST-JACQUES' 'PLANTES' 'LAENNEC' 'LOUIS XVI'
#  'LARIBOISIERE' 'ST-LOUIS' 'ILE DE BERCY' 'LA FAISANDERIE' 'ST-ANTOINE'
#  "PORTE D'IVRY" 'PARIS-MONTSOURIS' 'OBSERVATOIRE' 'OBS. TERRASSE'
#  'AUTEUIL' 'BAGATELLE' 'PASSY' 'MONTMARTRE' 'VILLETTE' 'HEROLD'
#  'BUTTES RESERV.' 'CHARONNE' 'MENIL.RESERVOIR' 'LUXEMBOURG'
#  'BUTTES CHAUMONT' 'VAUGIRARD' 'LEO LAGRANGE' 'CHAMP DE MARS' 'BELLEVILLE'
#  'BATIGNOLLES' 'SALPETRIERE' 'TENON' 'BELLEVILLE PARC' 'TOUR EIFFEL'
#  'G. POMPIDOU' 'LONGCHAMP' 'PARIS-MONTSOURIS-DOUBLE']
#
# Unique values in 'LAT_y': [48.860667 48.858333 48.843333 48.85     48.876667 48.882833 48.873333
#  48.831667 48.819833 48.848167 48.82     48.821667 48.836667 48.838333
#  48.841667 48.868667 48.87     48.886667 48.868333 48.878333 48.855
#  48.844667 48.876833 48.831    48.835    48.846667 48.887667 48.839167
#  48.865333 48.871333 48.838667 48.854833]
#
# Unique values in 'LON_y': [2.348333 2.363333 2.323333 2.328333 2.352    2.368333 2.411667 2.456833
#  2.380833 2.373333 2.337833 2.336667 2.268333 2.245333 2.291667 2.343333
#  2.381667 2.415    2.333833 2.299333 2.4375   2.296667 2.253333 2.315333
#  2.367333 2.402167 2.384667 2.2945   2.2745   2.233667]
#
# Unique values in 'ALTI_y': [ 37  38  35  36  55  48  50  54  58  75  62  91  39  78 138  57  72  97
#   83 108  46  49  34 130  45  94  80 330  32  27]
#
# Unique values in 'RR': [0.000e+00 1.800e+00 2.500e+00 1.900e+00 1.500e+00 1.000e+00 3.400e+00
#  3.000e+00 2.000e+00 1.700e+00 2.800e+00 2.600e+00 1.400e+00 2.400e+00
#  3.200e+00 2.300e+00 2.700e+00 5.200e+00 1.600e+00 8.800e+00 4.000e+00
#  14.1 11.1 13.5 12.5 13.4 15.8 12.2 17.3 18.  16.2 17.2 15.5 15.6 18.6
#   0.1 17.1  0.2 17.9 15.7 19.3 16.7 15.4 16.4]
#
# Unique values in 'QFFM': [nan  1.  2.  9.]
#
# Unique values in 'QFF2M': [nan  1.]
#
# Unique values in 'FXY': [ nan  3.   4.   5.   7.   6.   8.  11.   9.  10.  14.  12.  13.  16.
#   2.  15.   1.  17.  22.  18.  19.  24.  20.   0.  23.  25.  21.  26.
#  27.  28.  29.  40.   3.2  4.3  4.5  8.1  9.6  6.5  6.7  5.2  3.6  3.4
#   5.5  3.5  5.3  5.7  5.4  5.8  3.3  4.1  2.8  3.7  6.4  5.1  3.8  2.7
#   6.8  6.6  4.6  6.9  8.6  7.6  4.8  6.3  9.4  7.4  5.6  5.9  9.2  6.2
#   7.7  4.7  7.9  4.4  6.1  7.3  2.5  4.9  3.1  4.2  8.5  7.1  7.8  2.9
#   3.9  9.1  8.2  2.4  8.3  8.8 12.1  9.5  8.9  7.2 11.4 11.7  9.8 10.4
#  10.6  7.5  9.3  8.7  9.9 12.4 11.3  9.7  8.4 10.1  2.6 10.5 11.2 11.8
#   2.2  1.5  2.1 16.5 13.1 11.9  1.7  2.3  1.9 11.1 13.3 12.6  1.3  1.4
#  10.9 12.8 12.2 10.7 10.3  1.6 11.5 10.2 12.3 11.6 12.5 14.6 15.9 16.2
#  20.8 17.9 14.8 14.1 23.6 12.7 32.3 21.4 20.5 20.2 17.2 15.5 16.8 13.6
#  16.1 17.7 15.3 21.9 17.8 28.7 14.5 18.8 15.7 22.4 19.3 15.4 18.9 17.5
#  13.9 14.7 15.8 13.7 12.9 16.6 13.2 13.5 16.4 13.8 15.1 18.7 10.8 14.2
#  13.4 18.2 21.1 14.4 16.9 19.1 18.3 23.2 14.9 22.3 15.2 16.3 16.7  1.8
#  19.5 18.6 20.1 18.4 19.9 21.8 18.5 20.4 14.3 17.3 19.8 21.3 22.7 29.3
#  17.1 17.6 21.6 23.7 20.3 19.7 15.6 19.2 25.8 20.7 24.9 17.4]
#
# Unique values in 'QFXY': [nan  1.  2.]
#
# Unique values in 'DXY': [ nan 340.  20. 160.  40.  60.  80. 140. 120. 180. 220. 320. 200. 240.
#  360. 260. 300. 100. 280. 150. 110. 330. 230. 190. 170. 270. 210. 130.
#  350.  70.  90.  50.  10. 290.  30. 250. 310.   0.]
#
# Unique values in 'QDXY': [nan  1.  9.  2.]
#
# Unique values in 'HXY': [  nan 1235. 2330. ...  522.  519.  303.]
#
# Unique values in 'QHXY': [nan  1.  2.  9.]
#
# Unique values in 'FXI': [ nan  6.9  9.6 14.  10.7 12.3 11.7  8.2  5.8  5.2  5.   7.9  7.7  5.5
#  11.  12.7 16.8 13.7 17.4  8.8  8.7 11.9  3.8  3.7  8.   9.7  6.8  7.1
#  11.2 14.8 11.4 16.6 15.  23.6 23.7 13.3 16.5 22.1 23.4 19.8 26.6 13.4
#   6.4  8.5 21.7  4.7 13.6 12.9 20.3  9.4  7.4  4.4  4.   6.7  9.2 13.8
#   9.3 10.3  8.6 21.3 17.7 14.7 12.6  6.   7.3  9.1 24.6 16.3  9.   7.8
#  16.9 17.5 19.7 14.2 12.2 10.   7.6 14.3 10.4  8.4 20.6 18.8 27.3 16.7
#   8.9 13.5  9.8  7.2  7.   5.7 11.5  9.5 14.5 20.2 15.2 12.8 12.4 10.8
#  18.4 17.6  6.6  5.4  8.3 17.  14.4 18.5 10.6 14.1 11.3 17.3 13.2  7.5
#   6.5  5.6 15.8 10.5 17.2 13.1 14.6  6.1 15.3  4.6  4.3  2.5 19.  16.
#  22.  25.  28.7 15.5 16.2 26.8 11.1  2.8  3.2 15.6 18.7 17.1 25.6 17.9
#  14.9 15.7  6.2  5.9 10.1 11.6  3.6  3.1 26.  28.4 18.9 27.7 22.6 31.3
#  10.2  8.1  4.5 24.9 23.2 18.1 18.2 12.5 16.4 24.2 22.7 13.  15.1 13.9
#  12.   3.  10.9  9.9  3.5 19.2  4.9 19.3  6.3  4.8  5.3  4.1 12.1  2.7
#  21.1  5.1  3.4  1.6 22.2 22.3 15.4 22.5 20.8 29.  29.8  4.2 19.4 19.1
#  16.1 18.3 19.5 23.5 18.6 31.9  2.6 24.5  2.9  2.4  2.   3.9 34.7 11.8
#  30.1 20.1 23.3 20.  21.  21.4 20.7 15.9 20.4 24.4 23.8 25.3 21.9 17.8
#  21.2 21.8 20.5 28.3 25.7 21.6 24.1 19.9 20.9 29.5 22.4 22.9 24.3 26.4
#  24.7 25.8 19.6 18.  34.   2.2 30.7 33.  27.  32.  28.  23.  30.  24.
#  31.  37.  39.  36.   0.  38.  35.  42.  43.  60.  47.  40.  44.  27.6
#  23.1  2.1 33.8 25.1  3.3  0.1 28.9 22.8 27.2 26.1 29.6 30.3 24.8 21.5
#  25.9 28.8 27.8 25.4 29.1 26.3 32.8 26.2 26.7 27.9 37.7 44.1 25.5 29.7
#  27.1 30.5 29.2 23.9 38.7 30.2 32.5 36.8 26.9 39.7 31.7 25.2 27.4 32.6
#  41.3 28.2 29.9 31.5 31.6 41.7 32.2 33.9 29.4 37.6 27.5 29.3 35.4 38.4
#  35.2 31.2 34.2 32.4 36.7 30.4 37.4 42.3 33.4 36.9 35.9 32.3 26.5 34.9
#  40.6 38.8 35.5 34.3 42.6 28.6 30.9 32.9 37.5 31.8]
#
# Unique values in 'QFXI': [nan  1.  2.  9.]
#
# Unique values in 'DXI': [ nan 350.  40.  50. 250. 210. 170. 230. 270.  30. 330. 310. 290.  60.
#   70. 110. 150.  20. 130.  90.  80.  10. 100. 360. 120. 240. 340. 200.
#  260. 140. 280. 220. 320. 300. 180. 160.   0. 190.]
#
# Unique values in 'QDXI': [nan  1.  2.  9.]
#
# Unique values in 'HXI': [  nan 2030. 2325. ...  552.  804.  207.]
#
# Unique values in 'QHXI': [nan  1.  2.  9.]
#
# Unique values in 'FXI3S': [ nan 13.5 15.  10.4  5.2  6.2  9.6  9.2  6.5  8.5 11.3  7.8  7.9  9.1
#   8.6  9.9  7.4 11.7 10.2  9.3  6.3  6.6  5.7 10.7  6.   8.3  9.4  8.4
#   4.8  4.7  5.8  8.2  7.5  8.  14.4 21.7 17.3  8.8 14.7 22.5 10.3 11.2
#   4.9  7.3 10.1 10.6 12.6 12.4 19.7 22.2 10.5  5.6  5.1  6.9  4.3  8.1
#   7.  13.2 18.9 12.  16.2 14.3  8.9  9.7  6.7  9.  13.4 10.9 16.6 17.4
#  13.6 12.9 16.1 13.3 12.7 14.5 11.9  6.8  8.7  9.8 14.1 11.   5.3 10.8
#  12.8 12.1  5.4  7.6 15.3 11.6 13.1 12.5 11.8  5.5 11.1  5.9 11.5 21.9
#  13.9 13.8  7.1 17.2  6.1 13.   7.2 11.4  7.7 15.7 20.2 10.  18.5 16.5
#  17.6 17.5 13.7 12.2 15.8 16.7 16.  14.6 18.2 17.1 17.8 29.5 16.4 17.9
#  12.3 16.3 15.6  4.5  6.4  9.5 15.5 15.9 14.9  5.   4.  14.8 17.7  4.6
#  20.  16.8 22.8 14.  19.2 14.2 20.3 18.1 15.1 22.4 15.4 19.6 22.6  3.8
#  15.2 16.9 18.4  4.4 19.1 17.  18.  18.8 19.9 19.8  4.1  3.7 25.8 22.9
#  19.3 20.1  3.5 21.4 21.5 19.5 21.1 19.   3.  22.3 23.6  3.6  3.9  4.2
#  23.2 18.3 18.7 24.1 26.9 22.1 20.6  3.1 20.8 25.  23.1 25.5 21.2 23.4
#  26.3 19.4 29.1 20.5 18.6  2.9 28.5 21.8 24.6 24.5 36.1 24.8 24.  21.6
#  26.7 31.1 36.2 21.3 20.4 23.9 20.9 21.  29.  33.5 27.1 25.7 31.8 40.1
#  27.3  3.3 20.7 22.7 25.1 28.2 24.7 32.6 23.3 25.3 28.6 29.2 30.8 25.6
#  28.1 23.7 26.  24.2 22.  33.4 23.  32.  29.8 27.  31.2]
#
# Unique values in 'QFXI3S': [nan  1.  9.]
#
# Unique values in 'QDXI3S': [nan  9.]
#
# Unique values in 'HXI3S': [  nan 1157. 1329. ... 1126. 1105. 1826.]
#
# Unique values in 'QHXI3S': [nan  9.  1.]

# %%
merged_df.info
# Out:
# <bound method DataFrame.info of          NUM_POSTE_x       NOM_USUEL_x      LAT_x     LON_x  ALTI_x  AAAAMMJJ  \
# 0           75114001  PARIS-MONTSOURIS  48.821667  2.337833      75  19500101
# 1           75114001  PARIS-MONTSOURIS  48.821667  2.337833      75  19500101
# 2           75114001  PARIS-MONTSOURIS  48.821667  2.337833      75  19500101
# 3           75114001  PARIS-MONTSOURIS  48.821667  2.337833      75  19500101
# 4           75114001  PARIS-MONTSOURIS  48.821667  2.337833      75  19500101
# ...              ...               ...        ...       ...     ...       ...
# 2719127     75116008         LONGCHAMP  48.854833  2.233667      27  20221231
# 2719128     75116008         LONGCHAMP  48.854833  2.233667      27  20221231
# 2719129     75116008         LONGCHAMP  48.854833  2.233667      27  20221231
# 2719130     75116008         LONGCHAMP  48.854833  2.233667      27  20221231
# 2719131     75116008         LONGCHAMP  48.854833  2.233667      27  20221231
#
#          PMERM  QPMERM  PMERMIN  QPMERMIN  ...  QFXI    DXI  QDXI     HXI  \
# 0          NaN     NaN      NaN       NaN  ...   NaN    NaN   NaN     NaN
# 1          NaN     NaN      NaN       NaN  ...   NaN    NaN   NaN     NaN
# 2          NaN     NaN      NaN       NaN  ...   NaN    NaN   NaN     NaN
# 3          NaN     NaN      NaN       NaN  ...   NaN    NaN   NaN     NaN
# 4          NaN     NaN      NaN       NaN  ...   NaN    NaN   NaN     NaN
# ...        ...     ...      ...       ...  ...   ...    ...   ...     ...
# 2719127    NaN     NaN      NaN       NaN  ...   NaN    NaN   NaN     NaN
# 2719128    NaN     NaN      NaN       NaN  ...   1.0  220.0   1.0   139.0
# 2719129    NaN     NaN      NaN       NaN  ...   NaN    NaN   NaN     NaN
# 2719130    NaN     NaN      NaN       NaN  ...   1.0  180.0   9.0  1930.0
# 2719131    NaN     NaN      NaN       NaN  ...   NaN    NaN   NaN     NaN
#
#          QHXI  FXI3S  QFXI3S  QDXI3S   HXI3S  QHXI3S
# 0         NaN    NaN     NaN     NaN     NaN     NaN
# 1         NaN    NaN     NaN     NaN     NaN     NaN
# 2         NaN    NaN     NaN     NaN     NaN     NaN
# 3         NaN    NaN     NaN     NaN     NaN     NaN
# 4         NaN    NaN     NaN     NaN     NaN     NaN
# ...       ...    ...     ...     ...     ...     ...
# 2719127   NaN    NaN     NaN     NaN     NaN     NaN
# 2719128   9.0   16.2     1.0     NaN   139.0     9.0
# 2719129   NaN    NaN     NaN     NaN     NaN     NaN
# 2719130   9.0   14.9     9.0     NaN  1931.0     9.0
# 2719131   NaN    NaN     NaN     NaN     NaN     NaN
#
# [2719132 rows x 117 columns]>

# %%
filtered_data = merged_df[
    (merged_df['NUM_POSTE_x'] == 75114001) &
    (merged_df['NOM_USUEL_x'] == 'PARIS-MONTSOURIS') &
    (merged_df['AAAAMMJJ'] == 19500101)
]

# Check each row in the filtered dataset
for index, row in filtered_data.iterrows():
    # Filter out all null values for the current row, retaining only non-null columns
    non_null_data = row[row.notna()]
    # Print the non-null columns and their values for the current row
    print(f"Row {index} non-null data:")
    print(non_null_data)
    print("\n")  # Adding a newline for better readability between rows
# Out:
# Row 0 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75101001
# NOM_USUEL_y           INNOCENTS
# LAT_y                 48.860667
# LON_y                  2.348333
# ALTI_y                       37
# RR                          0.0
# QRR                         1.0
# Name: 0, dtype: object
#
#
# Row 1 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75104001
# NOM_USUEL_y     TOUR ST-JACQUES
# LAT_y                 48.858333
# LON_y                  2.348333
# ALTI_y                       38
# RR                          0.0
# QRR                         1.0
# Name: 1, dtype: object
#
#
# Row 2 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75105001
# NOM_USUEL_y             PLANTES
# LAT_y                 48.843333
# LON_y                  2.363333
# ALTI_y                       35
# RR                          0.0
# QRR                         1.0
# Name: 2, dtype: object
#
#
# Row 3 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75107001
# NOM_USUEL_y             LAENNEC
# LAT_y                     48.85
# LON_y                  2.323333
# ALTI_y                       36
# RR                          0.0
# QRR                         1.0
# Name: 3, dtype: object
#
#
# Row 4 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75108001
# NOM_USUEL_y           LOUIS XVI
# LAT_y                 48.876667
# LON_y                  2.328333
# ALTI_y                       35
# RR                          0.0
# QRR                         1.0
# Name: 4, dtype: object
#
#
# Row 5 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75110001
# NOM_USUEL_y        LARIBOISIERE
# LAT_y                 48.882833
# LON_y                     2.352
# ALTI_y                       55
# RR                          0.0
# QRR                         1.0
# Name: 5, dtype: object
#
#
# Row 6 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75110002
# NOM_USUEL_y            ST-LOUIS
# LAT_y                 48.873333
# LON_y                  2.368333
# ALTI_y                       48
# RR                          0.0
# QRR                         1.0
# Name: 6, dtype: object
#
#
# Row 7 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75112001
# NOM_USUEL_y        ILE DE BERCY
# LAT_y                 48.831667
# LON_y                  2.411667
# ALTI_y                       50
# RR                          0.0
# QRR                         1.0
# Name: 7, dtype: object
#
#
# Row 8 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75112002
# NOM_USUEL_y      LA FAISANDERIE
# LAT_y                 48.819833
# LON_y                  2.456833
# ALTI_y                       54
# RR                          0.0
# QRR                         1.0
# Name: 8, dtype: object
#
#
# Row 9 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75112004
# NOM_USUEL_y          ST-ANTOINE
# LAT_y                 48.848167
# LON_y                  2.380833
# ALTI_y                       36
# RR                          0.0
# QRR                         1.0
# Name: 9, dtype: object
#
#
# Row 10 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75113001
# NOM_USUEL_y        PORTE D'IVRY
# LAT_y                     48.82
# LON_y                  2.373333
# ALTI_y                       58
# RR                          0.0
# QRR                         1.0
# Name: 10, dtype: object
#
#
# Row 11 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75114001
# NOM_USUEL_y    PARIS-MONTSOURIS
# LAT_y                 48.821667
# LON_y                  2.337833
# ALTI_y                       75
# RR                          0.0
# QRR                         1.0
# TN                         -1.7
# QTN                         1.0
# TX                          2.4
# QTX                         1.0
# TM                          0.3
# QTM                         1.0
# TNTXM                       0.4
# QTNTXM                      1.0
# TAMPLI                      4.1
# QTAMPLI                     1.0
# FXI                         6.9
# QFXI                        1.0
# Name: 11, dtype: object
#
#
# Row 12 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75114002
# NOM_USUEL_y        OBSERVATOIRE
# LAT_y                 48.836667
# LON_y                  2.336667
# ALTI_y                       62
# RR                          0.0
# QRR                         1.0
# Name: 12, dtype: object
#
#
# Row 13 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75114003
# NOM_USUEL_y       OBS. TERRASSE
# LAT_y                 48.838333
# LON_y                  2.336667
# ALTI_y                       91
# RR                          0.0
# QRR                         1.0
# Name: 13, dtype: object
#
#
# Row 14 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75116001
# NOM_USUEL_y             AUTEUIL
# LAT_y                 48.841667
# LON_y                  2.268333
# ALTI_y                       39
# RR                          0.0
# QRR                         1.0
# Name: 14, dtype: object
#
#
# Row 15 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75116002
# NOM_USUEL_y           BAGATELLE
# LAT_y                 48.868667
# LON_y                  2.245333
# ALTI_y                       36
# RR                          0.0
# QRR                         1.0
# Name: 15, dtype: object
#
#
# Row 16 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75116003
# NOM_USUEL_y               PASSY
# LAT_y                     48.87
# LON_y                  2.291667
# ALTI_y                       78
# RR                          0.0
# QRR                         1.0
# Name: 16, dtype: object
#
#
# Row 17 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75118001
# NOM_USUEL_y          MONTMARTRE
# LAT_y                 48.886667
# LON_y                  2.343333
# ALTI_y                      138
# RR                          0.0
# QRR                         1.0
# Name: 17, dtype: object
#
#
# Row 18 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75119002
# NOM_USUEL_y            VILLETTE
# LAT_y                 48.868333
# LON_y                  2.336667
# ALTI_y                       57
# RR                          0.0
# QRR                         1.0
# Name: 18, dtype: object
#
#
# Row 19 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75119003
# NOM_USUEL_y              HEROLD
# LAT_y                 48.868333
# LON_y                  2.336667
# ALTI_y                       72
# RR                          0.0
# QRR                         1.0
# Name: 19, dtype: object
#
#
# Row 20 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75119004
# NOM_USUEL_y      BUTTES RESERV.
# LAT_y                 48.878333
# LON_y                  2.381667
# ALTI_y                       97
# RR                          0.0
# QRR                         1.0
# Name: 20, dtype: object
#
#
# Row 21 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75120001
# NOM_USUEL_y            CHARONNE
# LAT_y                    48.855
# LON_y                     2.415
# ALTI_y                       83
# RR                          0.0
# QRR                         1.0
# Name: 21, dtype: object
#
#
# Row 22 non-null data:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75120002
# NOM_USUEL_y     MENIL.RESERVOIR
# LAT_y                 48.876667
# LON_y                  2.411667
# ALTI_y                      108
# RR                          0.0
# QRR                         1.0
# Name: 22, dtype: object

# %%
import pandas as pd

# Assuming filtered_data is already defined as specified
filtered_data = merged_df[
    (merged_df['NUM_POSTE_x'] == 75114001) &
    (merged_df['NOM_USUEL_x'] == 'PARIS-MONTSOURIS') &
    (merged_df['AAAAMMJJ'] == 19500101)
]

non_null_rows = []  # List to store non-null rows

# Iterate over each row in the filtered dataset
for index, row in filtered_data.iterrows():
    # Filter out all null values for the current row, retaining only non-null columns
    non_null_data = row[row.notna()]
    
    # Add the non-null data to the list as a dictionary
    non_null_rows.append(non_null_data.to_dict())

    # Optionally print each non-null row
    # print(f"Row {index} non-null data:")
     #print(non_null_data)
    print("\n")  # Adding a newline for better readability between rows

# Create a new DataFrame from the list of non-null rows
non_null_dataframe = pd.DataFrame(non_null_rows)

# Check the new DataFrame
non_null_dataframe


row_11 = non_null_dataframe.iloc[11]  # Use .iloc to access by integer location

row_11
# Out:
# NUM_POSTE_x            75114001
# NOM_USUEL_x    PARIS-MONTSOURIS
# LAT_x                 48.821667
# LON_x                  2.337833
# ALTI_x                       75
# AAAAMMJJ               19500101
# INST                      375.0
# QINST                       9.0
# SIGMA                      77.0
# QSIGMA                      9.0
# UN                         70.0
# QUN                         1.0
# UX                         92.0
# QUX                         1.0
# QNEIGETOTX                  1.0
# NEIG                        0.0
# QNEIG                       9.0
# ORAG                        0.0
# QORAG                       9.0
# GRESIL                      0.0
# QGRESIL                     9.0
# GRELE                       0.0
# QGRELE                      9.0
# NUM_POSTE_y            75114001
# NOM_USUEL_y    PARIS-MONTSOURIS
# LAT_y                 48.821667
# LON_y                  2.337833
# ALTI_y                       75
# RR                          0.0
# QRR                         1.0
# TN                         -1.7
# QTN                         1.0
# TX                          2.4
# QTX                         1.0
# TM                          0.3
# QTM                         1.0
# TNTXM                       0.4
# QTNTXM                      1.0
# TAMPLI                      4.1
# QTAMPLI                     1.0
# FXI                         6.9
# QFXI                        1.0
# Name: 11, dtype: object

# %%
import pandas as pd

# Load the datasets directly from the CSV files
df1 = pd.read_csv('Q_75_latest-2023-2024_autres-parametres.csv', sep=';')
df2 = pd.read_csv('Q_75_latest-2023-2024_RR-T-Vent.csv', sep=';')

# Merge the dataframes on 'AAAAMMJJ' and other relevant identifiers
merged_df = pd.merge(df1, df2, on=['AAAAMMJJ', 'NUM_POSTE', 'NOM_USUEL', 'LAT', 'LON'], how='outer')

# Drop columns where all elements are NaN
merged_df.dropna(axis=1, how='all', inplace=True)

# Display the merged DataFrame after dropping NaN-only columns
merged_df.head()

# Optionally, you can save this cleaned DataFrame to a new CSV
merged_df.to_csv('2023-2024-weather_cleaned.csv', index=False)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 
#  20231016 20231017 20231018 20231019 20231020 20231021 20231022 20231023
#  20231024 20231025 20231026 20231027 20231028 20231029 20231030 20231031
#  20231101 20231102 20231103 20231104 20231105 20231106 20231107 20231108
#  20231109 20231110 20231111 20231112 20231113 20231114 20231115 20231116
#  20231117 20231118 20231119 20231120 20231121 20231122 20231123 20231124
#  20231125 20231126 20231127 20231128 20231129 20231130 20231201 20231202
#  20231203 20231204 20231205 20231206 20231207 20231208 20231209 20231210
#  20231211 20231212 20231213 20231214 20231215 20231216 20231217 20231218
#  20231219 20231220 20231221 20231222 20231223 20231224 20231225 20231226
#  20231227 20231228 20231229 20231230 20231231 20240101 20240102 20240103
#  20240104 20240105 20240106 20240107 20240108 20240109 20240110 20240111
#  20240112 20240113 20240114 20240115 20240116 20240117 20240118 20240119
#  20240120 20240121 20240122 20240123 20240124 20240125 20240126 20240127
#  20240128 20240129 20240130 20240131 20240201 20240202 20240203 20240204
#  20240205 20240206 20240207 20240208 20240209 20240210 20240211 20240212
#  20240213 20240214 20240215 20240216 20240217 20240218 20240219 20240220
#  20240221 20240222 20240223 20240224 20240225 20240226 20240227 20240228
#  20240229 20240301 20240302 20240303 20240304 20240305 20240306 20240307
#  20240308 20240309 20240310 20240311 20240312 20240313 20240314 20240315
#  20240316 20240317 20240318 20240319 20240320 20240321 20240322 20240323
#  20240324 20240325 20240326 20240327 20240328 20240329 20240330 20240331
#  20240401 20240402 20240403 20240404 20240405 20240406 20240407 20240408
#  20240409 20240410 20240411 20240412 20240413 20240414 20240415 20240416
#  20240417 20240418 20240419 20240420 20240421 20240422 20240423 20240424
#  20240425 20240426 20240427 20240428]

# %%
import pandas as pd

# Load the datasets directly from the CSV files
df1 = pd.read_csv('Q_75_previous-1950-2022_RR-T-Vent.csv', sep=';')
df2 = pd.read_csv('Q_75_previous-1950-2022_autres-parametres.csv', sep=';')

# Assuming 'AAAAMMJJ' is the date column and both dataframes share this common column
# Adjust the column names according to your actual data structure if necessary
merged_df2 = pd.merge(df1, df2, on=['AAAAMMJJ', 'NUM_POSTE', 'NOM_USUEL', 'LAT', 'LON'], how='outer')
# Drop columns where all elements are NaN
merged_df2.dropna(axis=1, how='all', inplace=True)
# Display the merged DataFrame
merged_df2.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[86], line 9
#       5 df2 = pd.read_csv('Q_75_previous-1950-2022_autres-parametres.csv', sep=';')
#       7 # Assuming 'AAAAMMJJ' is the date column and both dataframes share this common column
#       8 # Adjust the column names according to your actual data structure if necessary
# ----> 9 merged_df2 = pd.merge(df1, df2, on=['AAAAMMJJ', 'NUM_POSTE', 'NOM_USUEL', 'LAT', 'LON'], how='outer')
#      10 # Drop columns where all elements are NaN
#      11 merged_df2.dropna(axis=1, how='all', inplace=True)
#
# File c:\Users\SKONIECZNY\anaconda3\envs\BigPipe\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File c:\Users\SKONIECZNY\anaconda3\envs\BigPipe\Lib\site-packages\pandas\core\reshape\merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#     893 if self.indicator:
#
# File c:\Users\SKONIECZNY\anaconda3\envs\BigPipe\Lib\site-packages\pandas\core\reshape\merge.py:879, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     877 left.columns = llabels
#     878 right.columns = rlabels
# --> 879 result = concat([left, right], axis=1, copy=copy)
#     880 return result
#
# File c:\Users\SKONIECZNY\anaconda3\envs\BigPipe\Lib\site-packages\pandas\core\reshape\concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)
#     392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File c:\Users\SKONIECZNY\anaconda3\envs\BigPipe\Lib\site-packages\pandas\core\reshape\concat.py:684, in _Concatenator.get_result(self)
#     680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
# --> 684 new_data = concatenate_managers(
#     685     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     686 )
#     687 if not self.copy and not using_copy_on_write():
#     688     new_data._consolidate_inplace()
#
# File c:\Users\SKONIECZNY\anaconda3\envs\BigPipe\Lib\site-packages\pandas\core\internals\concat.py:131, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     124 # Assertions disabled for performance
#     125 # for tup in mgrs_indexers:
#     126 #    # caller is responsible for ensuring this
#     127 #    indexers = tup[1]
#     128 #    assert concat_axis not in indexers
#     130 if concat_axis == 0:
# --> 131     mgrs = _maybe_reindex_columns_na_proxy(axes, mgrs_indexers, needs_copy)
#     132     return mgrs[0].concat_horizontal(mgrs, axes)
#     134 if len(mgrs_indexers) > 0 and mgrs_indexers[0][0].nblocks > 0:
#
# File c:\Users\SKONIECZNY\anaconda3\envs\BigPipe\Lib\site-packages\pandas\core\internals\concat.py:230, in _maybe_reindex_columns_na_proxy(axes, mgrs_indexers, needs_copy)
#     220         mgr = mgr.reindex_indexer(
#     221             axes[i],
#     222             indexers[i],
#    (...)
#     227             use_na_proxy=True,  # only relevant for i==0
#     228         )
#     229     if needs_copy and not indexers:
# --> 230         mgr = mgr.copy()
#     232     new_mgrs.append(mgr)
#     233 return new_mgrs
#
# File c:\Users\SKONIECZNY\anaconda3\envs\BigPipe\Lib\site-packages\pandas\core\internals\managers.py:604, in BaseBlockManager.copy(self, deep)
#     601         res._blklocs = self._blklocs.copy()
#     603 if deep:
# --> 604     res._consolidate_inplace()
#     605 return res
#
# File c:\Users\SKONIECZNY\anaconda3\envs\BigPipe\Lib\site-packages\pandas\core\internals\managers.py:1788, in BlockManager._consolidate_inplace(self)
#    1782 def _consolidate_inplace(self) -> None:
#    1783     # In general, _consolidate_inplace should only be called via
#    1784     #  DataFrame._consolidate_inplace, otherwise we will fail to invalidate
#    1785     #  the DataFrame's _item_cache. The exception is for newly-created
#    1786     #  BlockManager objects not yet attached to a DataFrame.
#    1787     if not self.is_consolidated():
# -> 1788         self.blocks = _consolidate(self.blocks)
#    1789         self._is_consolidated = True
#    1790         self._known_consolidated = True
#
# File c:\Users\SKONIECZNY\anaconda3\envs\BigPipe\Lib\site-packages\pandas\core\internals\managers.py:2269, in _consolidate(blocks)
#    2267 new_blocks: list[Block] = []
#    2268 for (_can_consolidate, dtype), group_blocks in grouper:
# -> 2269     merged_blocks, _ = _merge_blocks(
#    2270         list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    2271     )
#    2272     new_blocks = extend_blocks(merged_blocks, new_blocks)
#    2273 return tuple(new_blocks)
#
# File c:\Users\SKONIECZNY\anaconda3\envs\BigPipe\Lib\site-packages\pandas\core\internals\managers.py:2301, in _merge_blocks(blocks, dtype, can_consolidate)
#    2298     new_values = bvals2[0]._concat_same_type(bvals2, axis=0)
#    2300 argsort = np.argsort(new_mgr_locs)
# -> 2301 new_values = new_values[argsort]
#    2302 new_mgr_locs = new_mgr_locs[argsort]
#    2304 bp = BlockPlacement(new_mgr_locs)
#
# MemoryError: Unable to allocate 313. MiB for an array with shape (83, 494315) and data type float64

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

# Initialize a SparkSession
spark = SparkSession.builder \
    .appName("Merge CSV Data") \
    .getOrCreate()

# Load the datasets
df1 = spark.read.csv('Q_75_previous-1950-2022_RR-T-Vent.csv', header=True, sep=';', inferSchema=True)
df2 = spark.read.csv('Q_75_previous-1950-2022_autres-parametres.csv', header=True, sep=';', inferSchema=True)

# Assuming 'AAAAMMJJ' is the date column and both dataframes share this common column
# Adjust the column names according to your actual data structure if necessary
merged_df = df1.join(df2, ['AAAAMMJJ', 'NUM_POSTE', 'NOM_USUEL', 'LAT', 'LON'], how='outer')

# Drop columns where all elements are NaN
# In PySpark, you'd typically handle this by filtering or using dropna if you know specific columns
# For dropping columns with all nulls, we need to compute this conditionally
for column in merged_df.columns:
    non_null_count = merged_df.filter(col(column).isNotNull()).count()
    if non_null_count == 0:
        merged_df = merged_df.drop(column)

# Show the result
merged_df.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 from pyspark.sql import SparkSession
#       2 from pyspark.sql.functions import col
#       4 # Initialize a SparkSession
#
# ModuleNotFoundError: No module named 'pyspark'
